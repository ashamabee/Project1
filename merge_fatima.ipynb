# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import gmaps
import json as json
from scipy.stats import linregress
from api_keys import yelp_key

# %%
#fair oaks, elk grove, east sac, florin arden arcade

# %%
headers = {'Authorization': 'Bearer %s' % yelp_key}
url = "https://api.yelp.com/v3/businesses/search"
params = {'term':'restaurant','location':'Fair Oaks','radius':'40000','limit':'50','offset':'900'}
req=requests.get(url, params=params, headers=headers)
response = req.json()
clean_json = json.loads(json.dumps(response))
fair_df = clean_json['businesses']
fair_df = pd.DataFrame(fair_df)

# %%
headers = {'Authorization': 'Bearer %s' % yelp_key}
url = "https://api.yelp.com/v3/businesses/search"
params = {'term':'restaurant','location':'Arden Arcade','radius':'40000','limit':'50','offset':'900'}
req=requests.get(url, params=params, headers=headers)
response = req.json()
clean_json = json.loads(json.dumps(response))
arden_df = clean_json['businesses']
arden_df = pd.DataFrame(arden_df)

# %%
headers = {'Authorization': 'Bearer %s' % yelp_key}
url = "https://api.yelp.com/v3/businesses/search"
params = {'term':'restaurant','location':'Elk Grove','radius':'40000','limit':'50','offset':'900'}
req=requests.get(url, params=params, headers=headers)
response = req.json()
clean_json = json.loads(json.dumps(response))
elk_df = clean_json['businesses']
elk_df = pd.DataFrame(elk_df)

# %%
headers = {'Authorization': 'Bearer %s' % yelp_key}
url = "https://api.yelp.com/v3/businesses/search"
params = {'term':'restaurant','location':'East Sacramento','radius':'40000','limit':'50','offset':'900'}
req=requests.get(url, params=params, headers=headers)
response = req.json()
clean_json = json.loads(json.dumps(response))
east_df = clean_json['businesses']
east_df = pd.DataFrame(east_df)

# %%
headers = {'Authorization': 'Bearer %s' % yelp_key}
url = "https://api.yelp.com/v3/businesses/search"
params = {'term':'restaurant','location':'Florin','radius':'40000','limit':'50','offset':'900'}
req=requests.get(url, params=params, headers=headers)
response = req.json()
clean_json = json.loads(json.dumps(response))
florin_df = clean_json['businesses']
florin_df = pd.DataFrame(florin_df)

# %%
#merge
fairarden= pd.DataFrame.append(fair_df,arden_df,ignore_index=True,verify_integrity=True)

# %%
elkeast= pd.DataFrame.append(elk_df,east_df,ignore_index=True,verify_integrity=True)

# %%
fairelk= pd.DataFrame.append(fairarden,elkeast,ignore_index=True,verify_integrity=True)

# %%
allmerge= pd.DataFrame.append(elkeast,fairelk,ignore_index=True,verify_integrity=True)

# %%
allmerge
# Out:
#                          id                                          alias  \
# 0    kGdMHpFw9Bp3VZCbkEIZ4A     las-palmas-bakery-and-pupusas-sacramento-2
# 1    _P_ipzHtinw7iKUONINNxw          don-quixotes-mexican-grill-sacramento
# 2    ISBq11rteW5LqWIYHRcTzA                in-n-out-burger-west-sacramento
# 3    MSIh4W1wg4ewn4ETJIea1Q                 sourdough-and-co-sacramento-28
# 4    ev_19RokJ21B8DjcJZmgDw                  chada-thai-cuisine-sacramento
# ..                      ...                                            ...
# 195  gL_7frRo8Segp6-UonJTZA         popeyes-louisiana-kitchen-sacramento-5
# 196  o7052UGkz80V8cd42LVKYg                     burger-junction-sacramento
# 197  rW10OiHw_v-psGrB32sRmw                 honu-hawaiian-bbq-sacramento-2
# 198  nOn17CDzCzYRL_fV-yRVDA  west-sac-sports-bar-and-grill-west-sacramento
# 199  7saFjI5v5-2xdlmmLVp21Q                  shift-coffee-house-sacramento
#
#                               name  \
# ...

# %%
#output_data_file = "outputdata/cities.csv"

allmerge.to_csv("outputdata/yelp_fatima2.csv", encoding= "ISO-8859-1", index= False)

# %%
fooddata= allmerge[allmerge.duplicated(subset= ["id"])]
fooddata
# Out:
#                          id                                           alias  \
# 132  e3j2H-awJ-JHUwWW8X6A5w                     tacos-chavinda-sacramento-2
# 142  ZSt7dM_v6k9FNQeMYOM_aA                      tacos-jessica-2-sacramento
# 150  kGdMHpFw9Bp3VZCbkEIZ4A      las-palmas-bakery-and-pupusas-sacramento-2
# 151  _P_ipzHtinw7iKUONINNxw           don-quixotes-mexican-grill-sacramento
# 152  ISBq11rteW5LqWIYHRcTzA                 in-n-out-burger-west-sacramento
# 153  MSIh4W1wg4ewn4ETJIea1Q                  sourdough-and-co-sacramento-28
# 154  ev_19RokJ21B8DjcJZmgDw                   chada-thai-cuisine-sacramento
# 155  ZSt7dM_v6k9FNQeMYOM_aA                      tacos-jessica-2-sacramento
# 156  zmxPZYWqLpD9aOQFqdkkkQ              green-jade-restaurant-carmichael-2
# 157  JjBzfVcA-EhVOs3xy1qQ0A                     connies-drive-in-sacramento
# 158  hsw6xMIcNiqGkCUH4TAqSQ               lemon-grass-restaurant-sacramento
# ...

# %%
fooddata.drop_duplicates(subset="id", inplace=True)

fooddata
# Out:
# /Users/fatimadonato/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                          id                                           alias  \
# 132  e3j2H-awJ-JHUwWW8X6A5w                     tacos-chavinda-sacramento-2
# 142  ZSt7dM_v6k9FNQeMYOM_aA                      tacos-jessica-2-sacramento
# 150  kGdMHpFw9Bp3VZCbkEIZ4A      las-palmas-bakery-and-pupusas-sacramento-2
# 151  _P_ipzHtinw7iKUONINNxw           don-quixotes-mexican-grill-sacramento
# 152  ISBq11rteW5LqWIYHRcTzA                 in-n-out-burger-west-sacramento
# 153  MSIh4W1wg4ewn4ETJIea1Q                  sourdough-and-co-sacramento-28
# ...
