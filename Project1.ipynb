# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
from scipy.stats import linregress

# %%
# Create filepaths to JSON files
# Checkinfilepath = 'YelpData/yelp_academic_dataset_checkin.json'
# Tipfilepath = 'YelpData/yelp_academic_dataset_tip.json'
Covidfilepath = 'YelpData/yelp_academic_dataset_covid_features.json'
Businessfilepath = 'YelpData/yelp_academic_dataset_business.json'

# Load the JSON files into DFs
# CheckinDF = pd.read_json(Checkinfilepath, lines=True)
# TipDF = pd.read_json(Tipfilepath, lines=True)
CovidDF = pd.read_json(Covidfilepath, lines=True)
BusinessDF = pd.read_json(Businessfilepath, lines=True)

# %%
RestaurantsDF = BusinessDF['categories'].str.contains('Restaurants','Food')

# The object returned is a "GroupBy" object and cannot be viewed normally...
RestaurantsDF
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 209388     True
# 209389    False
# 209390     True
# 209391    False
# 209392    False
# Name: categories, Length: 209393, dtype: object

# %%
RestaurantsDF

# %%
# View the DF
CovidDF.head(10)
# Out:
#               business_id                                         highlights  \
# 0  9kXRUIkwdDtnAPO6tVo51g                                              FALSE
# 1  H6D5HOTfMjrZt7r1EObZ1g                                              FALSE
# 2  FYddq7fUtzobZcw4jOJgVA                                              FALSE
# 3  c75jLTjlgA9q3gImLEGT6w                                              FALSE
# 4  YfzPiY50h_10Sjlg3mnNWQ                                              FALSE
# 5  HqDRvA64BpGtjnzf9beE4Q                                              FALSE
# 6  4voKpEbJhrhLv3FR__JgLA  [{"identifier":"remote_services_during_covid_1...
# 7  S-xZzaHeMyMcqf66GAC4wA                                              FALSE
# 8  c9sQmFjO8NnaLAFOVqWivw                                              FALSE
# 9  64ZUb-llBHrnOcN_o1wA_A                                              FALSE
#
#   delivery or takeout Grubhub enabled Call To Action enabled  \
# ...

# %%
print(TipDF.head(10))

# %%
print(ReviewsDF.head(10))
