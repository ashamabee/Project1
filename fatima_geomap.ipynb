# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
g_key="AIzaSyBw2oaXwfKc8PDY8slvtki6QHLAJDIZvm0"

# Study data files
yelp_path = "Final_Yelp_Data.csv"

# Read the mouse data and the study results
yelpers = pd.read_csv(yelp_path)

# %%
yelpers
# Out:
#      Unnamed: 0                      id  \
# 0             0  Y3HNUBQJHAzWnnhk3iReiA
# 1             1  9GhIDT1D_8-0ZxKDIB2WpA
# 2             2  LwiOfwMNDndIPm3QSh8wFQ
# 3             3  myoaFyZ9RIG_p2rkOQiWlA
# 4             4  rQaH3Jr6BxFhX5pXa6W6_w
# ..          ...                     ...
# 608        1062  l7Fe3Q1YMHwZYBLcKR4tKA
# 609        1064  4QkgyBIyqxPzKL7Ul7u0Ig
# 610        1065  glX_vsxgkBeYuQJpiUOCqw
# 611        1067  sv8Nf0mexd6N_koap_Itsw
# 612        1069  NHsVI4KvHpe0l6cqoo39Mg
#
#                                            alias  \
# 0           junoon-flavors-of-india-sacramento-2
# 1                         shake-shack-sacramento
# 2                               south-sacramento
# 3               fixins-soul-kitchen-sacramento-2
# 4                      chando-s-tacos-sacramento
# ..                                           ...
# 608               smoke-junction-cafe-sacramento
# 609                      tealicious-sacramento-3
# 610  three-sisters-mexican-restaurant-sacramento
# 611            honey-baked-ham-company-fair-oaks
# 612            sourdough-and-co-citrus-heights-2
#
#                                  name  \
# 0             Junoon Flavors Of India
# 1                         Shake Shack
# 2                               South
# 3                 Fixins Soul Kitchen
# 4                      Chando’s Tacos
# ..                                ...
# 608               Smoke Junction Cafe
# 609                        Tealicious
# 610  Three Sisters Mexican Restaurant
# 611           Honey Baked Ham Company
# 612                   Sourdough & Co.
#
#                                              image_url  is_closed  \
# 0    https://s3-media1.fl.yelpcdn.com/bphoto/P7Pzdg...      False
# 1    https://s3-media3.fl.yelpcdn.com/bphoto/TxbovZ...      False
# 2    https://s3-media3.fl.yelpcdn.com/bphoto/yHsuXv...      False
# 3    https://s3-media4.fl.yelpcdn.com/bphoto/wVYnJG...      False
# 4    https://s3-media2.fl.yelpcdn.com/bphoto/yoraiB...      False
# ..                                                 ...        ...
# 608  https://s3-media2.fl.yelpcdn.com/bphoto/N70LJl...      False
# 609  https://s3-media2.fl.yelpcdn.com/bphoto/lcwSxz...      False
# 610  https://s3-media1.fl.yelpcdn.com/bphoto/viDs7a...      False
# 611  https://s3-media1.fl.yelpcdn.com/bphoto/Smk2uM...      False
# 612  https://s3-media1.fl.yelpcdn.com/bphoto/m_LCCz...      False
#
#                                                    url  review_count  \
# 0    https://www.yelp.com/biz/junoon-flavors-of-ind...            20
# 1    https://www.yelp.com/biz/shake-shack-sacrament...           168
# 2    https://www.yelp.com/biz/south-sacramento?adju...          1590
# 3    https://www.yelp.com/biz/fixins-soul-kitchen-s...           946
# 4    https://www.yelp.com/biz/chando-s-tacos-sacram...            14
# ..                                                 ...           ...
# 608  https://www.yelp.com/biz/smoke-junction-cafe-s...            32
# 609  https://www.yelp.com/biz/tealicious-sacramento...           169
# 610  https://www.yelp.com/biz/three-sisters-mexican...           403
# 611  https://www.yelp.com/biz/honey-baked-ham-compa...            66
# 612  https://www.yelp.com/biz/sourdough-and-co-citr...           116
#
#                                             categories  rating  \
# 0             [{'alias': 'indpak', 'title': 'Indian'}]     5.0
# 1    [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.0
# 2         [{'alias': 'southern', 'title': 'Southern'}]     4.0
# 3    [{'alias': 'soulfood', 'title': 'Soul Food'}, ...     4.5
# 4           [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
# ..                                                 ...     ...
# 608  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.0
# 609  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.0
# 610  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     3.0
# 611  [{'alias': 'meats', 'title': 'Meat Shops'}, {'...     3.5
# 612  [{'alias': 'salad', 'title': 'Salad'}, {'alias...     3.5
#
#                                            coordinates  \
# 0    {'latitude': 38.570471, 'longitude': -121.4571...
# 1    {'latitude': 38.568686, 'longitude': -121.487243}
# 2    {'latitude': 38.5687015705627, 'longitude': -1...
# 3      {'latitude': 38.55147, 'longitude': -121.46924}
# 4    {'latitude': 38.564075, 'longitude': -121.4340...
# ..                                                 ...
# 608  {'latitude': 38.7050490891277, 'longitude': -1...
# 609  {'latitude': 38.5275870192814, 'longitude': -1...
# 610     {'latitude': 38.56015, 'longitude': -121.4435}
# 611  {'latitude': 38.6623840332031, 'longitude': -1...
# 612  {'latitude': 38.664591, 'longitude': -121.272799}
#
#                transactions  \
# 0                        []
# 1              ['delivery']
# 2              ['delivery']
# 3              ['delivery']
# 4                        []
# ..                      ...
# 608            ['delivery']
# 609              ['pickup']
# 610  ['pickup', 'delivery']
# 611  ['pickup', 'delivery']
# 612            ['delivery']
#
#                                               location         phone  \
# 0    {'address1': '3672 J St', 'address2': None, 'a...  1.916943e+10
# 1    {'address1': '1710 R St', 'address2': 'Ste 190...  1.279321e+10
# 2    {'address1': '2005 11th St', 'address2': '', '...  1.916383e+10
# 3    {'address1': '3428 3rd Ave', 'address2': '', '...  1.917000e+10
# 4    {'address1': '5644 J St', 'address2': '', 'add...  1.916477e+10
# ..                                                 ...           ...
# 608  {'address1': '5859 Antelope Rd', 'address2': '...  1.916948e+10
# 609  {'address1': '5101 Freeport Blvd', 'address2':...  1.916759e+10
# 610  {'address1': '5100 Folsom Blvd', 'address2': '...  1.916453e+10
# 611  {'address1': '5300 Sunrise Blvd', 'address2': ...  1.916962e+10
# 612  {'address1': '5437 Sunrise Blvd', 'address2': ...  1.916823e+10
#
#       display_phone      distance price  Unnamed: 0.1
# 0    (916) 942-9796   1267.138005   NaN           NaN
# 1    (279) 321-4002   3883.061550   NaN           NaN
# 2    (916) 382-9722   4735.638709    $$           NaN
# 3    (916) 999-7685   3270.943674    $$           NaN
# 4    (916) 476-6312   1210.413973   NaN           NaN
# ..              ...           ...   ...           ...
# 608  (916) 947-8672  12195.276691     $         469.0
# 609  (916) 758-5179  12970.787834     $         471.0
# 610  (916) 452-7442   7158.401123    $$         474.0
# 611  (916) 962-1426  11650.635930     $         476.0
# 612  (916) 823-3900  11718.138728    $$         478.0
#
# [613 rows x 18 columns]

# %%
#compare each type of food and review count
# grab categories, name, review count, and rating
df = pd.DataFrame(yelpers, columns = ['name', 'categories', 'review_count', 'rating', 'transactions', 'coordinates']) 

df['transactions'] = df['transactions'].replace(
    {"['delivery']": "True", 
     "[]": "False",
     "['pickup', 'delivery']": "True", 
     "['delivery', 'pickup']": "True", 
     "['pickup']":  "False",
     "['restaurant_reservation', 'delivery']":"True", 
     "['restaurant_reservation', 'pickup', 'delivery']":"True",
     "['restaurant_reservation']":'Theft',
     "['restaurant_reservation', 'delivery', 'pickup']": "True",
    })

# %%
#geomap the restaurants with most reviews
#top 20 and low 20
#df = pd.DataFrame(df.row.str.split(' ',1).tolist(),
#                                 columns = ['coordinates'])
df['lat'], df['long'] = df['coordinates'].str.split(',', 1).str
df['lat']= df['lat'].str.replace("{'latitude':", "")
df['long'] = df['long'].str.replace("'longitude': ", "").str.replace("}", "")
df
df[['long', 'lat']]= df[['long', 'lat']].astype(float, errors= "ignore")
#df['long'].isna().sum()
df
# Out:
# C:\Users\smith\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   """
#                                  name  \
# 0             Junoon Flavors Of India
# 1                         Shake Shack
# 2                               South
# 3                 Fixins Soul Kitchen
# 4                      Chando’s Tacos
# ..                                ...
# 608               Smoke Junction Cafe
# 609                        Tealicious
# 610  Three Sisters Mexican Restaurant
# 611           Honey Baked Ham Company
# 612                   Sourdough & Co.
#
#                                             categories  review_count  rating  \
# 0             [{'alias': 'indpak', 'title': 'Indian'}]            20     5.0
# 1    [{'alias': 'burgers', 'title': 'Burgers'}, {'a...           168     3.0
# 2         [{'alias': 'southern', 'title': 'Southern'}]          1590     4.0
# 3    [{'alias': 'soulfood', 'title': 'Soul Food'}, ...           946     4.5
# 4           [{'alias': 'mexican', 'title': 'Mexican'}]            14     4.5
# ..                                                 ...           ...     ...
# 608  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...            32     4.0
# 609  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...           169     4.0
# 610  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...           403     3.0
# 611  [{'alias': 'meats', 'title': 'Meat Shops'}, {'...            66     3.5
# 612  [{'alias': 'salad', 'title': 'Salad'}, {'alias...           116     3.5
#
#     transactions                                        coordinates  \
# 0          False  {'latitude': 38.570471, 'longitude': -121.4571...
# 1           True  {'latitude': 38.568686, 'longitude': -121.487243}
# 2           True  {'latitude': 38.5687015705627, 'longitude': -1...
# 3           True    {'latitude': 38.55147, 'longitude': -121.46924}
# 4          False  {'latitude': 38.564075, 'longitude': -121.4340...
# ..           ...                                                ...
# 608         True  {'latitude': 38.7050490891277, 'longitude': -1...
# 609        False  {'latitude': 38.5275870192814, 'longitude': -1...
# 610         True     {'latitude': 38.56015, 'longitude': -121.4435}
# 611         True  {'latitude': 38.6623840332031, 'longitude': -1...
# 612         True  {'latitude': 38.664591, 'longitude': -121.272799}
#
#                    lat                long
# 0            38.570471        -121.4571694
# 1            38.568686         -121.487243
# 2     38.5687015705627   -121.497104891816
# 3             38.55147          -121.46924
# 4            38.564075       -121.43409833
# ..                 ...                 ...
# 608   38.7050490891277   -121.328696432458
# 609   38.5275870192814   -121.495912777778
# 610           38.56015           -121.4435
# 611   38.6623840332031   -121.271705627441
# 612          38.664591         -121.272799
#
# [613 rows x 8 columns]

# %%
df= df.sort_values("review_count", ascending= False)
top20= df.head(20)
# top20[['long', 'lat']]= top20[['long', 'lat']].astype(float)

top20
# Out:
#                           name  \
# 20          Ramen House Ryujin
# 15               Oz Korean BBQ
# 48           Iron Horse Tavern
# 40               Tres Hermanas
# 350                 Yard House
# 23       Sawasdee Thai Cuisine
# 135   Ella Dining Room and Bar
# 352          Four Sisters Cafe
# 120                Fox & Goose
# 36       Public House Downtown
# 37            The Coconut On T
# 2                        South
# 31                    Paesanos
# 343  Lazy Dog Restaurant & Bar
# 33    The Firehouse Restaurant
# 341            My Thai Kitchen
# 373                    Topgolf
# 354                     Zócalo
# 340           The Chef's Table
# 265  Evan's Kitchen & Catering
#
#                                             categories  review_count  rating  \
# 20   [{'alias': 'ramen', 'title': 'Ramen'}, {'alias...          2881     4.5
# 15   [{'alias': 'korean', 'title': 'Korean'}, {'ali...          2647     4.0
# 48   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...          2435     4.0
# 40          [{'alias': 'mexican', 'title': 'Mexican'}]          2397     4.0
# 350  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...          2071     3.5
# 23                [{'alias': 'thai', 'title': 'Thai'}]          2021     4.5
# 135  [{'alias': 'newamerican', 'title': 'American (...          1756     4.0
# 352  [{'alias': 'breakfast_brunch', 'title': 'Break...          1749     4.5
# 120  [{'alias': 'breakfast_brunch', 'title': 'Break...          1729     3.5
# 36   [{'alias': 'newamerican', 'title': 'American (...          1705     4.0
# 37   [{'alias': 'thai', 'title': 'Thai'}, {'alias':...          1618     4.5
# 2         [{'alias': 'southern', 'title': 'Southern'}]          1590     4.0
# 31   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...          1550     4.0
# 343  [{'alias': 'newamerican', 'title': 'American (...          1485     4.0
# 33   [{'alias': 'newamerican', 'title': 'American (...          1422     4.0
# 341               [{'alias': 'thai', 'title': 'Thai'}]          1389     4.0
# 373  [{'alias': 'newamerican', 'title': 'American (...          1350     4.0
# 354         [{'alias': 'mexican', 'title': 'Mexican'}]          1315     4.0
# 340  [{'alias': 'newamerican', 'title': 'American (...          1271     4.5
# 265  [{'alias': 'tradamerican', 'title': 'American ...          1186     4.0
#
#     transactions                                        coordinates  \
# 20          True      {'latitude': 38.5674, 'longitude': -121.4857}
# 15          True    {'latitude': 38.56349, 'longitude': -121.33496}
# 48          True  {'latitude': 38.5695762064691, 'longitude': -1...
# 40          True    {'latitude': 38.57369, 'longitude': -121.47456}
# 350         True  {'latitude': 38.768878772817, 'longitude': -12...
# 23          True  {'latitude': 38.576894, 'longitude': -121.481515}
# 135         True     {'latitude': 38.57887, 'longitude': -121.4914}
# 352         True  {'latitude': 38.784513, 'longitude': -121.266579}
# 120         True  {'latitude': 38.5715283845259, 'longitude': -1...
# 36          True  {'latitude': 38.576166714481, 'longitude': -12...
# 37          True     {'latitude': 38.5685, 'longitude': -121.49658}
# 2           True  {'latitude': 38.5687015705627, 'longitude': -1...
# 31          True  {'latitude': 38.573753, 'longitude': -121.483764}
# 343         True  {'latitude': 38.7750242, 'longitude': -121.275...
# 33          True  {'latitude': 38.581539, 'longitude': -121.504931}
# 341         True  {'latitude': 38.7530926018765, 'longitude': -1...
# 373        False   {'latitude': 38.79075, 'longitude': -121.295726}
# 354         True  {'latitude': 38.76814736, 'longitude': -121.26...
# 340         True  {'latitude': 38.7964080881302, 'longitude': -1...
# 265         True  {'latitude': 38.5660479112045, 'longitude': -1...
#
#                    lat                long
# 20             38.5674           -121.4857
# 15            38.56349          -121.33496
# 48    38.5695762064691   -121.490668354958
# 40            38.57369          -121.47456
# 350    38.768878772817    -121.26806509957
# 23           38.576894         -121.481515
# 135           38.57887           -121.4914
# 352          38.784513         -121.266579
# 120   38.5715283845259   -121.496972802439
# 36     38.576166714481   -121.486355956124
# 37             38.5685          -121.49658
# 2     38.5687015705627   -121.497104891816
# 31           38.573753         -121.483764
# 343         38.7750242        -121.2752453
# 33           38.581539         -121.504931
# 341   38.7530926018765   -121.251939624905
# 373           38.79075         -121.295726
# 354        38.76814736       -121.26976408
# 340   38.7964080881302   -121.290666866223
# 265   38.5660479112045   -121.432719839287

# %%
df= df.sort_values("review_count", ascending= False)
tail= df[df["review_count"]==1]
tail[['long', 'lat']]= tail[['long', 'lat']].astype(float)
tail= tail[tail['long'] <-120]
tail
# Out:
# /Users/fatimadonato/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                                   name  \
# 451                        Burger King
# 146                      Baker Dozen 2
# 305                          TACOS GTO
# 482         Las Cachanillas Restaurant
# 506                 Mango’s Burger Bar
# 494                         Young Dong
# 313        Five-Twenty Four Restaurant
# 213                      El Zacatecano
# 246               Larosa's Sports Cafe
# 284                   Chili's Catering
# 65                   Outdoor Herbivore
# 460                            Cafe 26
# 262                    Sun Center Cafe
# 50              Playa Linda Del Carmen
# 480                         Café Hoshi
# 267                 Fair Oaks Pizzeria
# 162           Hall of Fame Bar & Grill
# 205             La Croissant Park Cafe
# 175                   Leonardi's Pizza
# 411        Riego Road Strawberry Stand
# 405                      Culinary Café
# 252                    Classic Burgers
# 535                     La Boheme Cafe
# 238                        3- N -1 BBQ
# 468        Bacchanal Bistro & Wine Bar
# 507  Virga's Restaurant Bar & Catering
#
#                                             categories  review_count  rating  \
# 451  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...             1     4.0
# 146  [{'alias': 'restaurants', 'title': 'Restaurant...             1     3.0
# 305  [{'alias': 'foodtrucks', 'title': 'Food Trucks...             1     5.0
# 482  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...             1     4.0
# 506  [{'alias': 'salad', 'title': 'Salad'}, {'alias...             1     4.0
# 494           [{'alias': 'korean', 'title': 'Korean'}]             1     1.0
# 313  [{'alias': 'restaurants', 'title': 'Restaurant...             1     2.0
# 213  [{'alias': 'newamerican', 'title': 'American (...             1     5.0
# 246  [{'alias': 'restaurants', 'title': 'Restaurant...             1     1.0
# 284  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...             1     5.0
# 65   [{'alias': 'diyfood', 'title': 'Do-It-Yourself...             1     5.0
# 460  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...             1     4.0
# 262             [{'alias': 'cafes', 'title': 'Cafes'}]             1     5.0
# 50     [{'alias': 'latin', 'title': 'Latin American'}]             1     5.0
# 480             [{'alias': 'cafes', 'title': 'Cafes'}]             1     5.0
# 267  [{'alias': 'restaurants', 'title': 'Restaurant...             1     1.0
# 162  [{'alias': 'newamerican', 'title': 'American (...             1     3.0
# 205  [{'alias': 'restaurants', 'title': 'Restaurant...             1     5.0
# 175             [{'alias': 'pizza', 'title': 'Pizza'}]             1     5.0
# 411  [{'alias': 'markets', 'title': 'Fruits & Veggi...             1     5.0
# 405             [{'alias': 'cafes', 'title': 'Cafes'}]             1     5.0
# 252  [{'alias': 'restaurants', 'title': 'Restaurant...             1     1.0
# 535  [{'alias': 'restaurants', 'title': 'Restaurant...             1     4.0
# 238            [{'alias': 'bbq', 'title': 'Barbeque'}]             1     5.0
# 468             [{'alias': 'pizza', 'title': 'Pizza'}]             1     5.0
# 507  [{'alias': 'restaurants', 'title': 'Restaurant...             1     4.0
#
#      transactions                                        coordinates  \
# 451            []  {'latitude': 38.6665820275127, 'longitude': -1...
# 146            []    {'latitude': 38.75193, 'longitude': -121.28109}
# 305            []     {'latitude': 38.6451, 'longitude': -121.44154}
# 482  ['delivery']  {'latitude': 38.60733833, 'longitude': -121.47...
# 506            []  {'latitude': 38.575439, 'longitude': -121.480671}
# 494  ['delivery']  {'latitude': 38.52425, 'longitude': -121.4971651}
# 313            []  {'latitude': 38.6097235232592, 'longitude': -1...
# 213            []  {'latitude': 38.5069695, 'longitude': -121.470...
# 246            []  {'latitude': 38.6421467, 'longitude': -121.383...
# 284            []    {'latitude': 38.66264, 'longitude': -121.27263}
# 65             []  {'latitude': 38.6095010505836, 'longitude': -1...
# 460            []    {'latitude': 38.74887, 'longitude': -121.26598}
# 262            []  {'latitude': 38.554607, 'longitude': -121.373375}
# 50             []  {'latitude': 38.690579, 'longitude': -121.4565...
# 480            []  {'latitude': 38.5782404, 'longitude': -121.487...
# 267            []      {'latitude': 38.639, 'longitude': -121.27424}
# 162  ['delivery']  {'latitude': 38.7098999, 'longitude': -121.291...
# 205            []  {'latitude': 38.5650634765625, 'longitude': -1...
# 175            []  {'latitude': 38.741153717041, 'longitude': -12...
# 411            []    {'latitude': 38.71598, 'longitude': -121.41362}
# 405            []  {'latitude': 38.602794, 'longitude': -121.418647}
# 252            []  {'latitude': 38.6098899841309, 'longitude': -1...
# 535            []    {'latitude': 38.57936, 'longitude': -121.49357}
# 238            []  {'latitude': 38.6270105, 'longitude': -121.445...
# 468            []    {'latitude': 38.74375, 'longitude': -121.25349}
# 507            []  {'latitude': 38.5730133056641, 'longitude': -1...
#
#            lat        long
# 451  38.666582 -121.388769
# 146  38.751930 -121.281090
# 305  38.645100 -121.441540
# 482  38.607338 -121.476527
# 506  38.575439 -121.480671
# 494  38.524250 -121.497165
# 313  38.609724 -121.475631
# 213  38.506969 -121.470070
# 246  38.642147 -121.383989
# 284  38.662640 -121.272630
# 65   38.609501 -121.367493
# 460  38.748870 -121.265980
# 262  38.554607 -121.373375
# 50   38.690579 -121.456554
# 480  38.578240 -121.487862
# 267  38.639000 -121.274240
# 162  38.709900 -121.291313
# 205  38.565063 -121.408081
# 175  38.741154 -121.249260
# 411  38.715980 -121.413620
# 405  38.602794 -121.418647
# 252  38.609890 -121.400833
# 535  38.579360 -121.493570
# 238  38.627010 -121.445811
# 468  38.743750 -121.253490
# 507  38.573013 -121.490189

# %%
gmaps.configure(api_key=g_key)

# %%
# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>name</dt><dd>{name}</dd>
<dt>lat</dt><dd>{lat}</dd>
<dt>long</dt><dd>{long}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
yelptop = [info_box_template.format(**row) for index, row in top20.iterrows()]
locations = top20[["lat", "long"]]
# use above variables for layer[]
#markers= gmaps.marker_layer(locations, hotel_info) #info_box_template)
fig = gmaps.figure()

markers= gmaps.marker_layer(locations, info_box_content=yelptop)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
yelptail = [info_box_template.format(**row) for index, row in tail.iterrows()]
locations = tail[["lat", "long"]]
# use above variables for layer[]
#markers= gmaps.marker_layer(locations, hotel_info) #info_box_template)
fig = gmaps.figure()

markers= gmaps.marker_layer(locations, info_box_content=yelptail)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
