# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

from api_keys import g_key
# %matplotlib inline
# !jupyter nbextension enable --py gmaps
# Out:
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok

# %%
csv_path = 'Final_Yelp_Data.csv'
yelp_df = pd.read_csv(csv_path)
yelp_df.sort_values("price")
# Out:
#      Unnamed: 0                      id                            alias  \
# 315         628  nyhDbHQzN9BtAm0Yl-070A          taco-bell-sacramento-26
# 481         804  7l8Xb3_OJVBv1YKbmBSPBQ          cottage-mart-sacramento
# 276         384  PMNWrUrYDXotf8r6CieUow              dennys-sacramento-5
# 275         383  HUHsugwczQ1lv_Q9Uc-TnA              subway-carmichael-8
# 273         381  Mi7dIyKoE0wFCoYznF8yUg          mcdonalds-sacramento-23
# ..          ...                     ...                              ...
# 572         913  SgHyS607EoH4FK-shSXeCA          cozy-kitchen-sacramento
# 579         926  1eT0Wcx4B1R5cLm15fFGIg             lucky-wok-sacramento
# 587        1036  t-LgC8KgOZO0KElAUcHCsw         melys-churros-sacramento
# 595        1047  RVYkgN638ZbJANFAN6Zgmg      tacos-brambila-sacramento-2
# 597        1049  sV3vZHeFuy-w3BTOohFr4g  milano-gourmet-pizza-carmichael
#
#                         name  \
# 315                Taco Bell
# 481             Cottage Mart
# 276                  Denny's
# 275                   Subway
# 273               McDonald's
# ..                       ...
# 572             Cozy Kitchen
# 579                Lucky Wok
# 587           Mely's Churros
# 595  Tacos Brambila Catering
# 597     Milano Gourmet Pizza
#
#                                              image_url  is_closed  \
# 315  https://s3-media3.fl.yelpcdn.com/bphoto/lokm4d...      False
# 481  https://s3-media4.fl.yelpcdn.com/bphoto/GPOVKi...      False
# 276  https://s3-media1.fl.yelpcdn.com/bphoto/enz5-z...      False
# 275  https://s3-media2.fl.yelpcdn.com/bphoto/rtfCo2...      False
# 273  https://s3-media3.fl.yelpcdn.com/bphoto/St6XAe...      False
# ..                                                 ...        ...
# 572  https://s3-media4.fl.yelpcdn.com/bphoto/fo0Foc...      False
# 579  https://s3-media3.fl.yelpcdn.com/bphoto/TgYlah...      False
# 587  https://s3-media1.fl.yelpcdn.com/bphoto/QMl6l5...      False
# 595  https://s3-media1.fl.yelpcdn.com/bphoto/iUhw42...      False
# 597  https://s3-media1.fl.yelpcdn.com/bphoto/_0PIIw...      False
#
#                                                    url  review_count  \
# 315  https://www.yelp.com/biz/taco-bell-sacramento-...            52
# 481  https://www.yelp.com/biz/cottage-mart-sacramen...            44
# 276  https://www.yelp.com/biz/dennys-sacramento-5?a...           103
# 275  https://www.yelp.com/biz/subway-carmichael-8?a...            38
# 273  https://www.yelp.com/biz/mcdonalds-sacramento-...            72
# ..                                                 ...           ...
# 572  https://www.yelp.com/biz/cozy-kitchen-sacramen...            15
# 579  https://www.yelp.com/biz/lucky-wok-sacramento?...           102
# 587  https://www.yelp.com/biz/melys-churros-sacrame...             8
# 595  https://www.yelp.com/biz/tacos-brambila-sacram...            21
# 597  https://www.yelp.com/biz/milano-gourmet-pizza-...             4
#
#                                             categories  rating  \
# 315  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     2.5
# 481  [{'alias': 'grocery', 'title': 'Grocery'}, {'a...     4.5
# 276  [{'alias': 'diners', 'title': 'Diners'}, {'ali...     2.5
# 275   [{'alias': 'sandwiches', 'title': 'Sandwiches'}]     2.0
# 273  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     2.0
# ..                                                 ...     ...
# 572         [{'alias': 'chinese', 'title': 'Chinese'}]     4.5
# 579  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.0
# 587  [{'alias': 'foodtrucks', 'title': 'Food Trucks...     4.5
# 595  [{'alias': 'foodtrucks', 'title': 'Food Trucks...     5.0
# 597             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
#
#                                            coordinates  \
# 315  {'latitude': 38.638117, 'longitude': -121.477428}
# 481  {'latitude': 38.5537109375, 'longitude': -121....
# 276  {'latitude': 38.6600960622725, 'longitude': -1...
# 275   {'latitude': 38.638536, 'longitude': -121.32934}
# 273  {'latitude': 38.65991805901, 'longitude': -121...
# ..                                                 ...
# 572  {'latitude': 38.6439497, 'longitude': -121.382...
# 579  {'latitude': 38.5983467, 'longitude': -121.383...
# 587   {'latitude': 38.525223, 'longitude': -121.45486}
# 595  {'latitude': 38.5243503261488, 'longitude': -1...
# 597     {'latitude': 38.63293, 'longitude': -121.3276}
#
#                transactions  \
# 315            ['delivery']
# 481            ['delivery']
# 276  ['pickup', 'delivery']
# 275                      []
# 273            ['delivery']
# ..                      ...
# 572  ['delivery', 'pickup']
# 579  ['delivery', 'pickup']
# 587                      []
# 595                      []
# 597  ['pickup', 'delivery']
#
#                                               location         phone  \
# 315  {'address1': '3820 Northgate Blvd', 'address2'...  1.916649e+10
# 481  {'address1': '2130 51st St', 'address2': '', '...  1.916740e+10
# 276  {'address1': '5120 Interstate Ave', 'address2'...  1.916332e+10
# 275  {'address1': '4005 Manzanita Ave', 'address2':...  1.916485e+10
# 273  {'address1': '5008 Auburn Blvd', 'address2': '...  1.916333e+10
# ..                                                 ...           ...
# 572  {'address1': '4332 Watt Ave', 'address2': 'Ste...           NaN
# 579  {'address1': '1853 Watt Ave', 'address2': None...  1.916489e+10
# 587  {'address1': '4441 Fruitridge Rd', 'address2':...  1.916704e+10
# 595  {'address1': '5615 Franklin Blvd', 'address2':...  1.916418e+10
# 597  {'address1': '7250 Fair Oaks Blvd', 'address2'...  1.916516e+10
#
#       display_phone      distance price  Unnamed: 0.1
# 315  (916) 649-1790  12605.418771     $          28.0
# 481  (916) 739-6310   8585.561784     $         204.0
# 276  (916) 331-7782   4272.642727     $           NaN
# 275  (916) 484-9200    833.468338     $           NaN
# 273  (916) 332-6951   3534.298139     $           NaN
# ..              ...           ...   ...           ...
# 572             NaN  10102.814858   NaN         313.0
# 579  (916) 488-7474   6444.326872   NaN         326.0
# 587  (916) 704-1289  10748.023362   NaN         438.0
# 595  (916) 417-8459  11703.547937   NaN         451.0
# 597  (916) 515-9510   5812.801034   NaN         453.0
#
# [613 rows x 18 columns]

# %%
del yelp_df['Unnamed: 0.1'],yelp_df['Unnamed: 0'],yelp_df['distance'],yelp_df['is_closed']
del yelp_df['image_url'],yelp_df['phone'],yelp_df['display_phone'],yelp_df['id'], yelp_df['alias'], yelp_df["url"]
yelp_df.head()
# Out:
#                       name  review_count  \
# 0  Junoon Flavors Of India            20
# 1              Shake Shack           168
# 2                    South          1590
# 3      Fixins Soul Kitchen           946
# 4           Chando’s Tacos            14
#
#                                           categories  rating  \
# 0           [{'alias': 'indpak', 'title': 'Indian'}]     5.0
# 1  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.0
# 2       [{'alias': 'southern', 'title': 'Southern'}]     4.0
# 3  [{'alias': 'soulfood', 'title': 'Soul Food'}, ...     4.5
# 4         [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
#
#                                          coordinates  transactions  \
# 0  {'latitude': 38.570471, 'longitude': -121.4571...            []
# 1  {'latitude': 38.568686, 'longitude': -121.487243}  ['delivery']
# 2  {'latitude': 38.5687015705627, 'longitude': -1...  ['delivery']
# 3    {'latitude': 38.55147, 'longitude': -121.46924}  ['delivery']
# 4  {'latitude': 38.564075, 'longitude': -121.4340...            []
#
#                                             location price
# 0  {'address1': '3672 J St', 'address2': None, 'a...   NaN
# 1  {'address1': '1710 R St', 'address2': 'Ste 190...   NaN
# 2  {'address1': '2005 11th St', 'address2': '', '...    $$
# 3  {'address1': '3428 3rd Ave', 'address2': '', '...    $$
# 4  {'address1': '5644 J St', 'address2': '', 'add...   NaN

# %%
yelp_df['transactions'].value_counts()
# Out:
# ['delivery']                                        269
# []                                                  161
# ['pickup', 'delivery']                               92
# ['delivery', 'pickup']                               76
# ['pickup']                                            7
# ['restaurant_reservation', 'delivery']                3
# ['restaurant_reservation']                            2
# ['restaurant_reservation', 'pickup', 'delivery']      2
# ['restaurant_reservation', 'delivery', 'pickup']      1
# Name: transactions, dtype: int64

# %%
yelp_df['transactions'] = yelp_df['transactions'].replace(
    {"['delivery']": "True", 
     "[]": "False",
     "['pickup', 'delivery']": "True", 
     "['delivery', 'pickup']": "True", 
     "['pickup']":  "False",
     "['restaurant_reservation', 'delivery']":"True", 
     "['restaurant_reservation', 'pickup', 'delivery']":"True",
     "['restaurant_reservation']":'Theft',
     "['restaurant_reservation', 'delivery', 'pickup']": "True",
    })

# %%
yelp_df.head()
# Out:
#                       name  review_count  \
# 0  Junoon Flavors Of India            20
# 1              Shake Shack           168
# 2                    South          1590
# 3      Fixins Soul Kitchen           946
# 4           Chando’s Tacos            14
#
#                                           categories  rating  \
# 0           [{'alias': 'indpak', 'title': 'Indian'}]     5.0
# 1  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.0
# 2       [{'alias': 'southern', 'title': 'Southern'}]     4.0
# 3  [{'alias': 'soulfood', 'title': 'Soul Food'}, ...     4.5
# 4         [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
#
#                                          coordinates transactions  \
# 0  {'latitude': 38.570471, 'longitude': -121.4571...        False
# 1  {'latitude': 38.568686, 'longitude': -121.487243}         True
# 2  {'latitude': 38.5687015705627, 'longitude': -1...         True
# 3    {'latitude': 38.55147, 'longitude': -121.46924}         True
# 4  {'latitude': 38.564075, 'longitude': -121.4340...        False
#
#                                             location price
# 0  {'address1': '3672 J St', 'address2': None, 'a...   NaN
# 1  {'address1': '1710 R St', 'address2': 'Ste 190...   NaN
# 2  {'address1': '2005 11th St', 'address2': '', '...    $$
# 3  {'address1': '3428 3rd Ave', 'address2': '', '...    $$
# 4  {'address1': '5644 J St', 'address2': '', 'add...   NaN

# %%
price_group = yelp_df.groupby("price").mean()
price_group
# Out:
#        review_count    rating
# price
# $        134.664122  3.309160
# $$       393.865217  3.682609
# $$$      609.200000  4.000000
# $$$$     705.000000  4.000000

# %%
price_group = price_group.rename({"$":"1","$$":"2","$$$":"3","$$$$":"4"})
price_group
# Out:
#        review_count    rating
# price
# 1        134.664122  3.309160
# 2        393.865217  3.682609
# 3        609.200000  4.000000
# 4        705.000000  4.000000

# %%
plt.plot(price_group)
# Out:
# [<matplotlib.lines.Line2D at 0x17a1e17ce48>,
#  <matplotlib.lines.Line2D at 0x17a1e88ca88>]

# %%
yelp_df = yelp_df.rename(columns={"name":"Restaurant Name", "review_count":"Review Count","categories":"Categories","rating":"Rating","transactions":"Delivery","location":"Address","price":"Price","coordinates":"Coordinates"})
yelp_df
# Out:
#                       Restaurant Name  Review Count  \
# 0             Junoon Flavors Of India            20
# 1                         Shake Shack           168
# 2                               South          1590
# 3                 Fixins Soul Kitchen           946
# 4                      Chando’s Tacos            14
# ..                                ...           ...
# 608               Smoke Junction Cafe            32
# 609                        Tealicious           169
# 610  Three Sisters Mexican Restaurant           403
# 611           Honey Baked Ham Company            66
# 612                   Sourdough & Co.           116
#
#                                             Categories  Rating  \
# 0             [{'alias': 'indpak', 'title': 'Indian'}]     5.0
# 1    [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.0
# 2         [{'alias': 'southern', 'title': 'Southern'}]     4.0
# 3    [{'alias': 'soulfood', 'title': 'Soul Food'}, ...     4.5
# 4           [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
# ..                                                 ...     ...
# 608  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.0
# 609  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.0
# 610  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     3.0
# 611  [{'alias': 'meats', 'title': 'Meat Shops'}, {'...     3.5
# 612  [{'alias': 'salad', 'title': 'Salad'}, {'alias...     3.5
#
#                                            Coordinates Delivery  \
# 0    {'latitude': 38.570471, 'longitude': -121.4571...    False
# 1    {'latitude': 38.568686, 'longitude': -121.487243}     True
# 2    {'latitude': 38.5687015705627, 'longitude': -1...     True
# 3      {'latitude': 38.55147, 'longitude': -121.46924}     True
# 4    {'latitude': 38.564075, 'longitude': -121.4340...    False
# ..                                                 ...      ...
# 608  {'latitude': 38.7050490891277, 'longitude': -1...     True
# 609  {'latitude': 38.5275870192814, 'longitude': -1...    False
# 610     {'latitude': 38.56015, 'longitude': -121.4435}     True
# 611  {'latitude': 38.6623840332031, 'longitude': -1...     True
# 612  {'latitude': 38.664591, 'longitude': -121.272799}     True
#
#                                                Address Price
# 0    {'address1': '3672 J St', 'address2': None, 'a...   NaN
# 1    {'address1': '1710 R St', 'address2': 'Ste 190...   NaN
# 2    {'address1': '2005 11th St', 'address2': '', '...    $$
# 3    {'address1': '3428 3rd Ave', 'address2': '', '...    $$
# 4    {'address1': '5644 J St', 'address2': '', 'add...   NaN
# ..                                                 ...   ...
# 608  {'address1': '5859 Antelope Rd', 'address2': '...     $
# 609  {'address1': '5101 Freeport Blvd', 'address2':...     $
# 610  {'address1': '5100 Folsom Blvd', 'address2': '...    $$
# 611  {'address1': '5300 Sunrise Blvd', 'address2': ...     $
# 612  {'address1': '5437 Sunrise Blvd', 'address2': ...    $$
#
# [613 rows x 8 columns]

# %%
yelp_df.loc[0,"Coordinates"]
# Out:
# "{'latitude': 38.570471, 'longitude': -121.4571694}"

# %%
coord = yelp_df.Coordinates.str.replace(",|}","").str.split(expand=True,).drop([0,2],axis = 1)

# %%
coord
# Out:
#                     1                  3
# 0           38.570471       -121.4571694
# 1           38.568686        -121.487243
# 2    38.5687015705627  -121.497104891816
# 3            38.55147         -121.46924
# 4           38.564075      -121.43409833
# ..                ...                ...
# 608  38.7050490891277  -121.328696432458
# 609  38.5275870192814  -121.495912777778
# 610          38.56015          -121.4435
# 611  38.6623840332031  -121.271705627441
# 612         38.664591        -121.272799
#
# [613 rows x 2 columns]

# %%
yelp_sacramento = pd.merge(yelp_df, coord, left_index=True, right_index=True)
yelp_sacramento.head()
# Out:
#            Restaurant Name  Review Count  \
# 0  Junoon Flavors Of India            20
# 1              Shake Shack           168
# 2                    South          1590
# 3      Fixins Soul Kitchen           946
# 4           Chando’s Tacos            14
#
#                                           Categories  Rating  \
# 0           [{'alias': 'indpak', 'title': 'Indian'}]     5.0
# 1  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.0
# 2       [{'alias': 'southern', 'title': 'Southern'}]     4.0
# 3  [{'alias': 'soulfood', 'title': 'Soul Food'}, ...     4.5
# 4         [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
#
#                                          Coordinates Delivery  \
# 0  {'latitude': 38.570471, 'longitude': -121.4571...    False
# 1  {'latitude': 38.568686, 'longitude': -121.487243}     True
# 2  {'latitude': 38.5687015705627, 'longitude': -1...     True
# 3    {'latitude': 38.55147, 'longitude': -121.46924}     True
# 4  {'latitude': 38.564075, 'longitude': -121.4340...    False
#
#                                              Address Price                 1  \
# 0  {'address1': '3672 J St', 'address2': None, 'a...   NaN         38.570471
# 1  {'address1': '1710 R St', 'address2': 'Ste 190...   NaN         38.568686
# 2  {'address1': '2005 11th St', 'address2': '', '...    $$  38.5687015705627
# 3  {'address1': '3428 3rd Ave', 'address2': '', '...    $$          38.55147
# 4  {'address1': '5644 J St', 'address2': '', 'add...   NaN         38.564075
#
#                    3
# 0       -121.4571694
# 1        -121.487243
# 2  -121.497104891816
# 3         -121.46924
# 4      -121.43409833

# %%
yelp_sacramento.drop("Coordinates", axis=1, inplace=True)

# %%
yelp_sacramento.rename(columns={1:"Latitude",3:"Longitude"}, inplace=True)

# %%
yelp_sacramento
# Out:
#                       Restaurant Name  Review Count  \
# 0             Junoon Flavors Of India            20
# 1                         Shake Shack           168
# 2                               South          1590
# 3                 Fixins Soul Kitchen           946
# 4                      Chando’s Tacos            14
# ..                                ...           ...
# 608               Smoke Junction Cafe            32
# 609                        Tealicious           169
# 610  Three Sisters Mexican Restaurant           403
# 611           Honey Baked Ham Company            66
# 612                   Sourdough & Co.           116
#
#                                             Categories  Rating Delivery  \
# 0             [{'alias': 'indpak', 'title': 'Indian'}]     5.0    False
# 1    [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.0     True
# 2         [{'alias': 'southern', 'title': 'Southern'}]     4.0     True
# 3    [{'alias': 'soulfood', 'title': 'Soul Food'}, ...     4.5     True
# 4           [{'alias': 'mexican', 'title': 'Mexican'}]     4.5    False
# ..                                                 ...     ...      ...
# 608  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.0     True
# 609  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.0    False
# 610  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     3.0     True
# 611  [{'alias': 'meats', 'title': 'Meat Shops'}, {'...     3.5     True
# 612  [{'alias': 'salad', 'title': 'Salad'}, {'alias...     3.5     True
#
#                                                Address Price  \
# 0    {'address1': '3672 J St', 'address2': None, 'a...   NaN
# 1    {'address1': '1710 R St', 'address2': 'Ste 190...   NaN
# 2    {'address1': '2005 11th St', 'address2': '', '...    $$
# 3    {'address1': '3428 3rd Ave', 'address2': '', '...    $$
# 4    {'address1': '5644 J St', 'address2': '', 'add...   NaN
# ..                                                 ...   ...
# 608  {'address1': '5859 Antelope Rd', 'address2': '...     $
# 609  {'address1': '5101 Freeport Blvd', 'address2':...     $
# 610  {'address1': '5100 Folsom Blvd', 'address2': '...    $$
# 611  {'address1': '5300 Sunrise Blvd', 'address2': ...     $
# 612  {'address1': '5437 Sunrise Blvd', 'address2': ...    $$
#
#              Latitude          Longitude
# 0           38.570471       -121.4571694
# 1           38.568686        -121.487243
# 2    38.5687015705627  -121.497104891816
# 3            38.55147         -121.46924
# 4           38.564075      -121.43409833
# ..                ...                ...
# 608  38.7050490891277  -121.328696432458
# 609  38.5275870192814  -121.495912777778
# 610          38.56015          -121.4435
# 611  38.6623840332031  -121.271705627441
# 612         38.664591        -121.272799
#
# [613 rows x 9 columns]

# %%
yelp_sacramento["Latitude"] = pd.to_numeric(yelp_sacramento["Latitude"],errors="coerce")

# %%
yelp_sacramento["Longitude"] = pd.to_numeric(yelp_sacramento["Longitude"],errors="coerce")

# %%
yelp_sacramento.dropna(subset=["Latitude","Longitude"], inplace= True)

# %%
type(yelp_sacramento["Latitude"])
# Out:
# pandas.core.series.Series

# %%
info_box_template = """
<dl>
<dt>Restaurant Name</dt><dd>{Restaurant Name}</dd>
<dt>Rating</dt><dd>{Rating}</dd>
<dt>Review Count</dt><dd>{Review Count}</dd>
</dl>
"""
# Store the DataFrame Row


# NOTE: be sure to update with your DataFrame name
restaurant_info = [info_box_template.format(**row) for index, row in yelp_sacramento.iterrows()]
locations = yelp_sacramento[["Latitude", "Longitude"]]

# %%
gmaps.configure(api_key=g_key)

# %%
figure_layout = {
    'width': '600px',
    'height': '450px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
figure = gmaps.figure(layout=figure_layout)
markers = gmaps.marker_layer(locations, info_box_content=restaurant_info)
# Add the layer to the map
figure.add_layer(markers)

figure
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='450px', margin='0 auto 0 auto', padding='1px', wi…

# %%
coordinates = pd.DataFrame({
    "Latitude":yelp_sacramento["Latitude"],
    "Longitude":yelp_sacramento["Longitude"]
})

figure_layout = {
    'width': '600px',
    'height': '450px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}

fig = gmaps.figure(layout=figure_layout)
layer = gmaps.heatmap_layer(coordinates)
fig.add_layer(layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='450px', margin='0 auto 0 auto', padding='1px', wi…

# %%
sac_delivery_yes = yelp_sacramento[yelp_sacramento["Delivery"]=="True"]

# %%
sac_delivery_no = yelp_sacramento[yelp_sacramento["Delivery"]=="False"]
sac_delivery_no
# Out:
#              Restaurant Name  Review Count  \
# 0    Junoon Flavors Of India            20
# 4             Chando’s Tacos            14
# 7                    Maydoon            45
# 8       World Famous Hotboys             2
# 9       Midtown Taco Company            48
# ..                       ...           ...
# 590        Noodles & Company           221
# 595  Tacos Brambila Catering            21
# 604        Bacon MANia Truck           159
# 605       Bitu Liquor & Deli            12
# 609               Tealicious           169
#
#                                             Categories  Rating Delivery  \
# 0             [{'alias': 'indpak', 'title': 'Indian'}]     5.0    False
# 4           [{'alias': 'mexican', 'title': 'Mexican'}]     4.5    False
# 7    [{'alias': 'persian', 'title': 'Persian/Irania...     5.0    False
# 8    [{'alias': 'tradamerican', 'title': 'American ...     4.5    False
# 9               [{'alias': 'tacos', 'title': 'Tacos'}]     4.5    False
# ..                                                 ...     ...      ...
# 590  [{'alias': 'noodles', 'title': 'Noodles'}, {'a...     3.5    False
# 595  [{'alias': 'foodtrucks', 'title': 'Food Trucks...     5.0    False
# 604  [{'alias': 'tradamerican', 'title': 'American ...     3.5    False
# 605  [{'alias': 'beer_and_wine', 'title': 'Beer, Wi...     4.0    False
# 609  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.0    False
#
#                                                Address Price   Latitude  \
# 0    {'address1': '3672 J St', 'address2': None, 'a...   NaN  38.570471
# 4    {'address1': '5644 J St', 'address2': '', 'add...   NaN  38.564075
# 7    {'address1': '1501 16th St', 'address2': '', '...   NaN  38.572124
# 8    {'address1': '', 'address2': '', 'address3': N...   NaN  38.575329
# 9    {'address1': '1420 29th St', 'address2': '', '...   NaN  38.568390
# ..                                                 ...   ...        ...
# 590  {'address1': '6123 Sunrise Blvd', 'address2': ...     $  38.675172
# 595  {'address1': '5615 Franklin Blvd', 'address2':...   NaN  38.524350
# 604  {'address1': '1106 N D', 'address2': 'Ste 22',...    $$  38.592424
# 605  {'address1': '4901 Auburn Blvd', 'address2': N...     $  38.657240
# 609  {'address1': '5101 Freeport Blvd', 'address2':...     $  38.527587
#
#       Longitude
# 0   -121.457169
# 4   -121.434098
# 7   -121.487480
# 8   -121.467102
# 9   -121.470490
# ..          ...
# 590 -121.272990
# 595 -121.471205
# 604 -121.486058
# 605 -121.351340
# 609 -121.495913
#
# [167 rows x 9 columns]

# %%
coordinates = pd.DataFrame({
    "Latitude":sac_delivery_yes["Latitude"],
    "Longitude":sac_delivery_yes["Longitude"]
})

figure_layout = {
    'width': '600px',
    'height': '450px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}

fig_delivery = gmaps.figure(layout=figure_layout)
layer = gmaps.heatmap_layer(coordinates)
fig_delivery.add_layer(layer)
fig_delivery
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='450px', margin='0 auto 0 auto', padding='1px', wi…
