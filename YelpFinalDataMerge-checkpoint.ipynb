# %%
import os
import csv
import pandas as pd

# %%
file_one = os.path.join("projectdata.csv")
file_one_df = pd.read_csv(file_one)
file_one_df
# Out:
#                          id                                   alias  \
# 0    Y3HNUBQJHAzWnnhk3iReiA    junoon-flavors-of-india-sacramento-2
# 1    9GhIDT1D_8-0ZxKDIB2WpA                  shake-shack-sacramento
# 2    LwiOfwMNDndIPm3QSh8wFQ                        south-sacramento
# 3    myoaFyZ9RIG_p2rkOQiWlA        fixins-soul-kitchen-sacramento-2
# 4    rQaH3Jr6BxFhX5pXa6W6_w               chando-s-tacos-sacramento
# ..                      ...                                     ...
# 145  B6H6OuI3PlH_jd6sgCs5QQ                   tasty-palace-antelope
# 146  LiGK3zAv0VSjVCNolGxXAA   anthonys-italian-cuisine-sacramento-2
# 147  icwssDkQB6R_cufhWpTqFQ    tacos-el-sabroso-2-north-highlands-3
# 148  d9AtBkmw8j4ixK8tLH5aEg  colos-soul-food-and-seafood-sacramento
# 149  dLmYr-c4jB0aY4T0teJPoA            the-pizza-press-sacramento-5
#
#                            name  \
# 0       Junoon Flavors Of India
# 1                   Shake Shack
# 2                         South
# 3           Fixins Soul Kitchen
# 4                Chando’s Tacos
# ..                          ...
# 145                Tasty Palace
# 146   Anthony's Italian Cuisine
# 147          Tacos El Sabroso 2
# 148  Colo's Soul Food & Seafood
# 149             The Pizza Press
#
#                                              image_url  is_closed  \
# 0    https://s3-media1.fl.yelpcdn.com/bphoto/P7Pzdg...      False
# 1    https://s3-media3.fl.yelpcdn.com/bphoto/TxbovZ...      False
# 2    https://s3-media3.fl.yelpcdn.com/bphoto/yHsuXv...      False
# 3    https://s3-media4.fl.yelpcdn.com/bphoto/wVYnJG...      False
# 4    https://s3-media2.fl.yelpcdn.com/bphoto/yoraiB...      False
# ..                                                 ...        ...
# 145  https://s3-media2.fl.yelpcdn.com/bphoto/A5pGc3...      False
# 146  https://s3-media3.fl.yelpcdn.com/bphoto/v9Z9p5...      False
# 147  https://s3-media3.fl.yelpcdn.com/bphoto/cM3x5A...      False
# 148  https://s3-media3.fl.yelpcdn.com/bphoto/vWJcXz...      False
# 149  https://s3-media3.fl.yelpcdn.com/bphoto/fUGYhM...      False
#
#                                                    url  review_count  \
# 0    https://www.yelp.com/biz/junoon-flavors-of-ind...            20
# 1    https://www.yelp.com/biz/shake-shack-sacrament...           168
# 2    https://www.yelp.com/biz/south-sacramento?adju...          1590
# 3    https://www.yelp.com/biz/fixins-soul-kitchen-s...           946
# 4    https://www.yelp.com/biz/chando-s-tacos-sacram...            14
# ..                                                 ...           ...
# 145  https://www.yelp.com/biz/tasty-palace-antelope...           250
# 146  https://www.yelp.com/biz/anthonys-italian-cuis...           423
# 147  https://www.yelp.com/biz/tacos-el-sabroso-2-no...            72
# 148  https://www.yelp.com/biz/colos-soul-food-and-s...            55
# 149  https://www.yelp.com/biz/the-pizza-press-sacra...            98
#
#                                             categories  rating  \
# 0             [{'alias': 'indpak', 'title': 'Indian'}]     5.0
# 1    [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.0
# 2         [{'alias': 'southern', 'title': 'Southern'}]     4.0
# 3    [{'alias': 'soulfood', 'title': 'Soul Food'}, ...     4.5
# 4           [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
# ..                                                 ...     ...
# 145         [{'alias': 'chinese', 'title': 'Chinese'}]     3.5
# 146  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# 147  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.0
# 148  [{'alias': 'soulfood', 'title': 'Soul Food'}, ...     4.0
# 149  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
#
#                                            coordinates  \
# 0    {'latitude': 38.570471, 'longitude': -121.4571...
# 1    {'latitude': 38.568686, 'longitude': -121.487243}
# 2    {'latitude': 38.5687015705627, 'longitude': -1...
# 3      {'latitude': 38.55147, 'longitude': -121.46924}
# 4    {'latitude': 38.564075, 'longitude': -121.4340...
# ..                                                 ...
# 145  {'latitude': 38.7138894425707, 'longitude': -1...
# 146  {'latitude': 38.611899, 'longitude': -121.495741}
# 147    {'latitude': 38.69092, 'longitude': -121.38429}
# 148  {'latitude': 38.610825, 'longitude': -121.448708}
# 149  {'latitude': 38.6563932, 'longitude': -121.511...
#
#                transactions  \
# 0                        []
# 1              ['delivery']
# 2              ['delivery']
# 3              ['delivery']
# 4                        []
# ..                      ...
# 145  ['pickup', 'delivery']
# 146            ['delivery']
# 147  ['pickup', 'delivery']
# 148  ['pickup', 'delivery']
# 149  ['pickup', 'delivery']
#
#                                               location         phone  \
# 0    {'address1': '3672 J St', 'address2': None, 'a...  1.916943e+10
# 1    {'address1': '1710 R St', 'address2': 'Ste 190...  1.279321e+10
# 2    {'address1': '2005 11th St', 'address2': '', '...  1.916383e+10
# 3    {'address1': '3428 3rd Ave', 'address2': '', '...  1.917000e+10
# 4    {'address1': '5644 J St', 'address2': '', 'add...  1.916477e+10
# ..                                                 ...           ...
# 145  {'address1': '7943 Watt Ave', 'address2': 'Ste...  1.916331e+10
# 146  {'address1': '1518 W El Camino Ave', 'address2...  1.916565e+10
# 147  {'address1': '3525 Elkhorn Blvd', 'address2': ...  1.916271e+10
# 148  {'address1': '2326 Del Paso Blvd', 'address2':...  1.916693e+10
# 149  {'address1': '2281 Del Paso Rd', 'address2': '...  1.916928e+10
#
#       display_phone     distance price
# 0    (916) 942-9796  1267.138005   NaN
# 1    (279) 321-4002  3883.061550   NaN
# 2    (916) 382-9722  4735.638709    $$
# 3    (916) 999-7685  3270.943674    $$
# 4    (916) 476-6312  1210.413973   NaN
# ..              ...          ...   ...
# 145  (916) 331-1122  5603.151830    $$
# 146  (916) 564-6718  9293.773069    $$
# 147  (916) 270-8183  5638.687748     $
# 148  (916) 692-8948  8480.372966    $$
# 149  (916) 928-2113  6390.018793    $$
#
# [150 rows x 16 columns]

# %%
file_two = os.path.join("yelp_fatima2.csv")
file_two_df = pd.read_csv(file_two)

# %%
file_three = os.path.join("YelpData_Ashley.csv")
file_three_df = pd.read_csv(file_three)

# %%
file_four = os.path.join("YelpData_Maria.csv")
file_four_df = pd.read_csv(file_four)

# %%
merge_1 = pd.DataFrame.append(file_one_df,file_two_df,ignore_index=True,verify_integrity=True)

# %%
merge_2 = pd.DataFrame.append(merge_1,file_three_df,ignore_index=True,verify_integrity=True)

# %%
merge_3 = pd.DataFrame.append(merge_2,file_four_df,ignore_index=True,verify_integrity=True)

# %%
final_data = merge_3.drop_duplicates("id")
final_data
# Out:
#                           id                                        alias  \
# 0     Y3HNUBQJHAzWnnhk3iReiA         junoon-flavors-of-india-sacramento-2
# 1     9GhIDT1D_8-0ZxKDIB2WpA                       shake-shack-sacramento
# 2     LwiOfwMNDndIPm3QSh8wFQ                             south-sacramento
# 3     myoaFyZ9RIG_p2rkOQiWlA             fixins-soul-kitchen-sacramento-2
# 4     rQaH3Jr6BxFhX5pXa6W6_w                    chando-s-tacos-sacramento
# ...                      ...                                          ...
# 1062  l7Fe3Q1YMHwZYBLcKR4tKA               smoke-junction-cafe-sacramento
# 1064  4QkgyBIyqxPzKL7Ul7u0Ig                      tealicious-sacramento-3
# 1065  glX_vsxgkBeYuQJpiUOCqw  three-sisters-mexican-restaurant-sacramento
# 1067  sv8Nf0mexd6N_koap_Itsw            honey-baked-ham-company-fair-oaks
# 1069  NHsVI4KvHpe0l6cqoo39Mg            sourdough-and-co-citrus-heights-2
#
#                                   name  \
# 0              Junoon Flavors Of India
# 1                          Shake Shack
# 2                                South
# 3                  Fixins Soul Kitchen
# 4                       Chando’s Tacos
# ...                                ...
# 1062               Smoke Junction Cafe
# 1064                        Tealicious
# 1065  Three Sisters Mexican Restaurant
# 1067           Honey Baked Ham Company
# 1069                   Sourdough & Co.
#
#                                               image_url  is_closed  \
# 0     https://s3-media1.fl.yelpcdn.com/bphoto/P7Pzdg...      False
# 1     https://s3-media3.fl.yelpcdn.com/bphoto/TxbovZ...      False
# 2     https://s3-media3.fl.yelpcdn.com/bphoto/yHsuXv...      False
# 3     https://s3-media4.fl.yelpcdn.com/bphoto/wVYnJG...      False
# 4     https://s3-media2.fl.yelpcdn.com/bphoto/yoraiB...      False
# ...                                                 ...        ...
# 1062  https://s3-media2.fl.yelpcdn.com/bphoto/N70LJl...      False
# 1064  https://s3-media2.fl.yelpcdn.com/bphoto/lcwSxz...      False
# 1065  https://s3-media1.fl.yelpcdn.com/bphoto/viDs7a...      False
# 1067  https://s3-media1.fl.yelpcdn.com/bphoto/Smk2uM...      False
# 1069  https://s3-media1.fl.yelpcdn.com/bphoto/m_LCCz...      False
#
#                                                     url  review_count  \
# 0     https://www.yelp.com/biz/junoon-flavors-of-ind...            20
# 1     https://www.yelp.com/biz/shake-shack-sacrament...           168
# 2     https://www.yelp.com/biz/south-sacramento?adju...          1590
# 3     https://www.yelp.com/biz/fixins-soul-kitchen-s...           946
# 4     https://www.yelp.com/biz/chando-s-tacos-sacram...            14
# ...                                                 ...           ...
# 1062  https://www.yelp.com/biz/smoke-junction-cafe-s...            32
# 1064  https://www.yelp.com/biz/tealicious-sacramento...           169
# 1065  https://www.yelp.com/biz/three-sisters-mexican...           403
# 1067  https://www.yelp.com/biz/honey-baked-ham-compa...            66
# 1069  https://www.yelp.com/biz/sourdough-and-co-citr...           116
#
#                                              categories  rating  \
# 0              [{'alias': 'indpak', 'title': 'Indian'}]     5.0
# 1     [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.0
# 2          [{'alias': 'southern', 'title': 'Southern'}]     4.0
# 3     [{'alias': 'soulfood', 'title': 'Soul Food'}, ...     4.5
# 4            [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
# ...                                                 ...     ...
# 1062  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.0
# 1064  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.0
# 1065  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     3.0
# 1067  [{'alias': 'meats', 'title': 'Meat Shops'}, {'...     3.5
# 1069  [{'alias': 'salad', 'title': 'Salad'}, {'alias...     3.5
#
#                                             coordinates  \
# 0     {'latitude': 38.570471, 'longitude': -121.4571...
# 1     {'latitude': 38.568686, 'longitude': -121.487243}
# 2     {'latitude': 38.5687015705627, 'longitude': -1...
# 3       {'latitude': 38.55147, 'longitude': -121.46924}
# 4     {'latitude': 38.564075, 'longitude': -121.4340...
# ...                                                 ...
# 1062  {'latitude': 38.7050490891277, 'longitude': -1...
# 1064  {'latitude': 38.5275870192814, 'longitude': -1...
# 1065     {'latitude': 38.56015, 'longitude': -121.4435}
# 1067  {'latitude': 38.6623840332031, 'longitude': -1...
# 1069  {'latitude': 38.664591, 'longitude': -121.272799}
#
#                 transactions  \
# 0                         []
# 1               ['delivery']
# 2               ['delivery']
# 3               ['delivery']
# 4                         []
# ...                      ...
# 1062            ['delivery']
# 1064              ['pickup']
# 1065  ['pickup', 'delivery']
# 1067  ['pickup', 'delivery']
# 1069            ['delivery']
#
#                                                location         phone  \
# 0     {'address1': '3672 J St', 'address2': None, 'a...  1.916943e+10
# 1     {'address1': '1710 R St', 'address2': 'Ste 190...  1.279321e+10
# 2     {'address1': '2005 11th St', 'address2': '', '...  1.916383e+10
# 3     {'address1': '3428 3rd Ave', 'address2': '', '...  1.917000e+10
# 4     {'address1': '5644 J St', 'address2': '', 'add...  1.916477e+10
# ...                                                 ...           ...
# 1062  {'address1': '5859 Antelope Rd', 'address2': '...  1.916948e+10
# 1064  {'address1': '5101 Freeport Blvd', 'address2':...  1.916759e+10
# 1065  {'address1': '5100 Folsom Blvd', 'address2': '...  1.916453e+10
# 1067  {'address1': '5300 Sunrise Blvd', 'address2': ...  1.916962e+10
# 1069  {'address1': '5437 Sunrise Blvd', 'address2': ...  1.916823e+10
#
#        display_phone      distance price  Unnamed: 0
# 0     (916) 942-9796   1267.138005   NaN         NaN
# 1     (279) 321-4002   3883.061550   NaN         NaN
# 2     (916) 382-9722   4735.638709    $$         NaN
# 3     (916) 999-7685   3270.943674    $$         NaN
# 4     (916) 476-6312   1210.413973   NaN         NaN
# ...              ...           ...   ...         ...
# 1062  (916) 947-8672  12195.276691     $       469.0
# 1064  (916) 758-5179  12970.787834     $       471.0
# 1065  (916) 452-7442   7158.401123    $$       474.0
# 1067  (916) 962-1426  11650.635930     $       476.0
# 1069  (916) 823-3900  11718.138728    $$       478.0
#
# [714 rows x 17 columns]

# %%
final_data_sacramento = final_data[final_data['location'].str.contains("'CA'")]

# %%
final_data_sacramento
# Out:
#                           id                                        alias  \
# 0     Y3HNUBQJHAzWnnhk3iReiA         junoon-flavors-of-india-sacramento-2
# 1     9GhIDT1D_8-0ZxKDIB2WpA                       shake-shack-sacramento
# 2     LwiOfwMNDndIPm3QSh8wFQ                             south-sacramento
# 3     myoaFyZ9RIG_p2rkOQiWlA             fixins-soul-kitchen-sacramento-2
# 4     rQaH3Jr6BxFhX5pXa6W6_w                    chando-s-tacos-sacramento
# ...                      ...                                          ...
# 1062  l7Fe3Q1YMHwZYBLcKR4tKA               smoke-junction-cafe-sacramento
# 1064  4QkgyBIyqxPzKL7Ul7u0Ig                      tealicious-sacramento-3
# 1065  glX_vsxgkBeYuQJpiUOCqw  three-sisters-mexican-restaurant-sacramento
# 1067  sv8Nf0mexd6N_koap_Itsw            honey-baked-ham-company-fair-oaks
# 1069  NHsVI4KvHpe0l6cqoo39Mg            sourdough-and-co-citrus-heights-2
#
#                                   name  \
# 0              Junoon Flavors Of India
# 1                          Shake Shack
# 2                                South
# 3                  Fixins Soul Kitchen
# 4                       Chando’s Tacos
# ...                                ...
# 1062               Smoke Junction Cafe
# 1064                        Tealicious
# 1065  Three Sisters Mexican Restaurant
# 1067           Honey Baked Ham Company
# 1069                   Sourdough & Co.
#
#                                               image_url  is_closed  \
# 0     https://s3-media1.fl.yelpcdn.com/bphoto/P7Pzdg...      False
# 1     https://s3-media3.fl.yelpcdn.com/bphoto/TxbovZ...      False
# 2     https://s3-media3.fl.yelpcdn.com/bphoto/yHsuXv...      False
# 3     https://s3-media4.fl.yelpcdn.com/bphoto/wVYnJG...      False
# 4     https://s3-media2.fl.yelpcdn.com/bphoto/yoraiB...      False
# ...                                                 ...        ...
# 1062  https://s3-media2.fl.yelpcdn.com/bphoto/N70LJl...      False
# 1064  https://s3-media2.fl.yelpcdn.com/bphoto/lcwSxz...      False
# 1065  https://s3-media1.fl.yelpcdn.com/bphoto/viDs7a...      False
# 1067  https://s3-media1.fl.yelpcdn.com/bphoto/Smk2uM...      False
# 1069  https://s3-media1.fl.yelpcdn.com/bphoto/m_LCCz...      False
#
#                                                     url  review_count  \
# 0     https://www.yelp.com/biz/junoon-flavors-of-ind...            20
# 1     https://www.yelp.com/biz/shake-shack-sacrament...           168
# 2     https://www.yelp.com/biz/south-sacramento?adju...          1590
# 3     https://www.yelp.com/biz/fixins-soul-kitchen-s...           946
# 4     https://www.yelp.com/biz/chando-s-tacos-sacram...            14
# ...                                                 ...           ...
# 1062  https://www.yelp.com/biz/smoke-junction-cafe-s...            32
# 1064  https://www.yelp.com/biz/tealicious-sacramento...           169
# 1065  https://www.yelp.com/biz/three-sisters-mexican...           403
# 1067  https://www.yelp.com/biz/honey-baked-ham-compa...            66
# 1069  https://www.yelp.com/biz/sourdough-and-co-citr...           116
#
#                                              categories  rating  \
# 0              [{'alias': 'indpak', 'title': 'Indian'}]     5.0
# 1     [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.0
# 2          [{'alias': 'southern', 'title': 'Southern'}]     4.0
# 3     [{'alias': 'soulfood', 'title': 'Soul Food'}, ...     4.5
# 4            [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
# ...                                                 ...     ...
# 1062  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.0
# 1064  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.0
# 1065  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     3.0
# 1067  [{'alias': 'meats', 'title': 'Meat Shops'}, {'...     3.5
# 1069  [{'alias': 'salad', 'title': 'Salad'}, {'alias...     3.5
#
#                                             coordinates  \
# 0     {'latitude': 38.570471, 'longitude': -121.4571...
# 1     {'latitude': 38.568686, 'longitude': -121.487243}
# 2     {'latitude': 38.5687015705627, 'longitude': -1...
# 3       {'latitude': 38.55147, 'longitude': -121.46924}
# 4     {'latitude': 38.564075, 'longitude': -121.4340...
# ...                                                 ...
# 1062  {'latitude': 38.7050490891277, 'longitude': -1...
# 1064  {'latitude': 38.5275870192814, 'longitude': -1...
# 1065     {'latitude': 38.56015, 'longitude': -121.4435}
# 1067  {'latitude': 38.6623840332031, 'longitude': -1...
# 1069  {'latitude': 38.664591, 'longitude': -121.272799}
#
#                 transactions  \
# 0                         []
# 1               ['delivery']
# 2               ['delivery']
# 3               ['delivery']
# 4                         []
# ...                      ...
# 1062            ['delivery']
# 1064              ['pickup']
# 1065  ['pickup', 'delivery']
# 1067  ['pickup', 'delivery']
# 1069            ['delivery']
#
#                                                location         phone  \
# 0     {'address1': '3672 J St', 'address2': None, 'a...  1.916943e+10
# 1     {'address1': '1710 R St', 'address2': 'Ste 190...  1.279321e+10
# 2     {'address1': '2005 11th St', 'address2': '', '...  1.916383e+10
# 3     {'address1': '3428 3rd Ave', 'address2': '', '...  1.917000e+10
# 4     {'address1': '5644 J St', 'address2': '', 'add...  1.916477e+10
# ...                                                 ...           ...
# 1062  {'address1': '5859 Antelope Rd', 'address2': '...  1.916948e+10
# 1064  {'address1': '5101 Freeport Blvd', 'address2':...  1.916759e+10
# 1065  {'address1': '5100 Folsom Blvd', 'address2': '...  1.916453e+10
# 1067  {'address1': '5300 Sunrise Blvd', 'address2': ...  1.916962e+10
# 1069  {'address1': '5437 Sunrise Blvd', 'address2': ...  1.916823e+10
#
#        display_phone      distance price  Unnamed: 0
# 0     (916) 942-9796   1267.138005   NaN         NaN
# 1     (279) 321-4002   3883.061550   NaN         NaN
# 2     (916) 382-9722   4735.638709    $$         NaN
# 3     (916) 999-7685   3270.943674    $$         NaN
# 4     (916) 476-6312   1210.413973   NaN         NaN
# ...              ...           ...   ...         ...
# 1062  (916) 947-8672  12195.276691     $       469.0
# 1064  (916) 758-5179  12970.787834     $       471.0
# 1065  (916) 452-7442   7158.401123    $$       474.0
# 1067  (916) 962-1426  11650.635930     $       476.0
# 1069  (916) 823-3900  11718.138728    $$       478.0
#
# [613 rows x 17 columns]

# %%
final_data.to_csv("Final_Yelp_Data.csv")
